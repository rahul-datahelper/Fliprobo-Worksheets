# %% [markdown]
# # PYTHON – WORKSHEET 9

# %% [markdown]
# 1- a python dictionary
#
# 2- True
#
# 3- All of the above
#
# 4- Error
#
# 5- 3 dimensional
#
# 6- 1
#
# 7- in
#
# 8- value, size
#
# 9- A Data Frame is like a fixed-size dictionary in that you can get and set values by index label.
#
#    A key difference between Series and ndarray is that operations between Series automatically align the   data based on label
#
#    In pandas, Index values must be unique
#
# 10- JSON
#     CSV
#     TXT

# %% [markdown]
# 11-

# %%
import pandas as pd
import numpy as np

exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels =  ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X']

df = pd.DataFrame(exam_data , index=labels)
print(df)
# Out:
#            name  score  attempts qualify
# I     Anastasia   12.5         1     yes
# II         Dima    9.0         3      no
# III   Katherine   16.5         2     yes
# IV        James    NaN         3      no
# V         Emily    9.0         2      no
# VI      Michael   20.0         3     yes
# VII     Matthew   14.5         1     yes
# VIII      Laura    NaN         1      no
# IX        Kevin    8.0         2      no
# X         Jonas   19.0         1     yes

# %% [markdown]
# 12-

# %%
import pandas as pd
import numpy as np

exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels =  ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X']

df = pd.DataFrame(exam_data , index=labels)


print("First five rows of the data frame:")
print(df.iloc[:5])
# Out:
# First five rows of the data frame:
#           name  score  attempts qualify
# I    Anastasia   12.5         1     yes
# II        Dima    9.0         3      no
# III  Katherine   16.5         2     yes
# IV       James    NaN         3      no
# V        Emily    9.0         2      no

# %% [markdown]
# 13-

# %%
print("Select specific columns:")
print(df[['name', 'score']])
# Out:
# Select specific columns:
#            name  score
# I     Anastasia   12.5
# II         Dima    9.0
# III   Katherine   16.5
# IV        James    NaN
# V         Emily    9.0
# VI      Michael   20.0
# VII     Matthew   14.5
# VIII      Laura    NaN
# IX        Kevin    8.0
# X         Jonas   19.0

# %% [markdown]
# 14-

# %%
print("Select specific columns and rows:")
print(df.iloc[[ 3, 5, 6,8], [1, 3]])
# Out:
# Select specific columns and rows:
#      score qualify
# IV     NaN      no
# VI    20.0     yes
# VII   14.5     yes
# IX     8.0      no

# %% [markdown]
# 15-

# %%
print("Rows where score between 15 and 20 (inclusive):")
print(df[df['score'].between(15, 20)])
# Out:
# Rows where score between 15 and 20 (inclusive):
#           name  score  attempts qualify
# III  Katherine   16.5         2     yes
# VI     Michael   20.0         3     yes
# X        Jonas   19.0         1     yes
